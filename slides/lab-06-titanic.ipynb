# %% [markdown]
# # The `Titanic` dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
seed = 42
df = pd.read_csv('datasets/titanic/train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # Schema of the dataset
#
# |Attribute|Description|Value|
# |---------|-----------|-----|
# |survival| 	Survival| 	0 = No, 1 = Yes|
# |pclass| 	Ticket class| 	1 = 1st, 2 = 2nd, 3 = 3rd|
# |sex| 	Sex 	||
# |Age| 	Age in years| 	|
# |sibsp| 	# of siblings / spouses aboard the Titanic |	|
# |parch| 	# of parents / children aboard the Titanic 	||
# |ticket| 	Ticket number 	||
# |fare| 	Passenger fare 	||
# |cabin| 	Cabin number 	||
# |embarked| 	Port of Embarkation |	C = Cherbourg, Q = Queenstown, S = Southampton |

# %% [markdown]
# # Profiling

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # Plot `Survived`

# %%
fig, ax = plt.subplots(figsize=(4, 3))
df['Survived'].hist(ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# # Pre-processing

# %% [markdown]
# # Encoding `Sex`

# %%
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})
fig, ax = plt.subplots(figsize=(4, 3))
df['Sex'].hist(ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# # Imputing `Age`

# %%
df["Age"]=df["Age"].fillna(df["Age"].mean())

# %% [markdown]
# # Encoding `Embarked`

# %%
embarked_one_hot = pd.get_dummies(df['Embarked'], prefix='Embarked')
df = pd.concat([df, embarked_one_hot], axis=1)
df = df.drop('Embarked', axis=1)

# %%
df.describe(include="all").transpose()
# Out:
#              count unique                  top freq       mean         std  \
# PassengerId  891.0    NaN                  NaN  NaN      446.0  257.353842
# Survived     891.0    NaN                  NaN  NaN   0.383838    0.486592
# Pclass       891.0    NaN                  NaN  NaN   2.308642    0.836071
# Name           891    891  Dooley, Mr. Patrick    1        NaN         NaN
# Sex          891.0    NaN                  NaN  NaN   0.352413     0.47799
# Age          891.0    NaN                  NaN  NaN  29.699118   13.002015
# SibSp        891.0    NaN                  NaN  NaN   0.523008    1.102743
# Parch        891.0    NaN                  NaN  NaN   0.381594    0.806057
# Ticket         891    681               347082    7        NaN         NaN
# Fare         891.0    NaN                  NaN  NaN  32.204208   49.693429
# Cabin          204    147                   G6    4        NaN         NaN
# Embarked_C     891      2                False  723        NaN         NaN
# Embarked_Q     891      2                False  814        NaN         NaN
# Embarked_S     891      2                 True  644        NaN         NaN
#
#               min     25%        50%    75%       max
# PassengerId   1.0   223.5      446.0  668.5     891.0
# Survived      0.0     0.0        0.0    1.0       1.0
# Pclass        1.0     2.0        3.0    3.0       3.0
# Name          NaN     NaN        NaN    NaN       NaN
# Sex           0.0     0.0        0.0    1.0       1.0
# Age          0.42    22.0  29.699118   35.0      80.0
# SibSp         0.0     0.0        0.0    1.0       8.0
# Parch         0.0     0.0        0.0    0.0       6.0
# Ticket        NaN     NaN        NaN    NaN       NaN
# Fare          0.0  7.9104    14.4542   31.0  512.3292
# Cabin         NaN     NaN        NaN    NaN       NaN
# Embarked_C    NaN     NaN        NaN    NaN       NaN
# Embarked_Q    NaN     NaN        NaN    NaN       NaN
# Embarked_S    NaN     NaN        NaN    NaN       NaN

# %% [markdown]
# # Dropping useless columns

# %%
df = df.drop(['Name', 'PassengerId', 'Cabin', 'Ticket'], axis=1)

# %% [markdown]
# # Checking data distribution

# %%
df.hist()
plt.tight_layout()

# %% [markdown]
# # Correlation matrix

# %%
import seaborn as sns
correlation_matrix = df.corr()
plt.figure(figsize=(6, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
# Out:
# <Axes: >

# %% [markdown]
# # Checking correlation with survived

# %%
plt.figure(figsize=(6, 6))
sns.heatmap(correlation_matrix[['Survived']].sort_values(by="Survived", ascending=False), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation with Survival')
# Out:
# Text(0.5, 1.0, 'Correlation with Survival')

# %% [markdown]
# # Plotting the data (PCA)

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
X = df.drop(['Survived'], axis=1)
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents, columns = ['PC1', 'PC2'])
finalDf = pd.concat([principalDf, df[['Survived']]], axis = 1)
fig, ax = plt.subplots(figsize = (6, 6))
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_title('PCA')
targets, colors = [0, 1], ['r', 'g']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['Survived'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'PC1'], finalDf.loc[indicesToKeep, 'PC2'], c = color, s = 50, edgecolor='k')
ax.legend(['Not Survived', 'Survived'])
ax.grid()

# %% [markdown]
# # Plotting the data (T-SNE)

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

tsne = TSNE(n_components=2, random_state=seed)
tsne_results = tsne.fit_transform(X)
finalDf = pd.DataFrame({'TSNE1': tsne_results[:, 0], 'TSNE2': tsne_results[:, 1], 'Survived': df['Survived']})
fig, ax = plt.subplots(figsize = (6, 6))
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['Survived'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'TSNE1'], finalDf.loc[indicesToKeep, 'TSNE2'], c = color, s = 50, edgecolor='k')
plt.xlabel('TSNE1')
plt.ylabel('TSNE2')
ax.legend(['Not Survived', 'Survived'])
ax.grid()

# %% [markdown]
# # Compute a decision tree

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.tree import plot_tree
from sklearn.model_selection import RandomizedSearchCV, cross_val_score
X, y = df.drop('Survived', axis=1), df['Survived']

def train_tree(X, y, X_test=None, y_test=None):
    param_grid = {
        'criterion': ['gini', 'entropy'],
        'splitter': ['best', 'random'],
        'max_depth': [3, 5, 10, 15],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'max_features': ['sqrt', 'log2']
    }
    clf = DecisionTreeClassifier(random_state=seed)
    random_search = RandomizedSearchCV(estimator=clf, param_distributions=param_grid, n_iter=100, cv=5, scoring='accuracy', random_state=seed, error_score='raise')
    random_search.fit(X, y)
    best_clf = random_search.best_estimator_
    print("Best Classifier:", best_clf)
    test_score = None
    if X_test is not None:
        y_pred = best_clf.predict(X_test)
        test_score = accuracy_score(y_test, y_pred)
    return best_clf, float(random_search.best_score_), test_score

best_clf, train_score, test_score = train_tree(X, y)
train_score, test_score
# Out:
# Best Classifier: DecisionTreeClassifier(max_depth=10, max_features='log2', random_state=42)
# e:\OneDrive - Alma Mater Studiorum Università di Bologna\teaching-bigdata\AA2425-unibo-mldm\slides\venv\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# (0.8193522063900571, None)

# %% [markdown]
# # Understanding feature relevance

# %%
def feature_relevance(best_clf, X):
    feature_importances = pd.Series(best_clf.feature_importances_, index=X.columns).sort_values(ascending=False)
    # print(f"Feature Importance: \n{feature_importances}")
    fig, ax = plt.subplots(figsize=(4, 3))
    feature_importances.plot(kind='barh', ax=ax)
    for i in ax.patches: ax.text(i.get_width() + 0.01, i.get_y() + 0.2, f'{i.get_width():.2f}', fontsize=10, color='dimgrey')
    ax.set_xlabel('Importance')
    ax.set_ylabel('Feature')

feature_relevance(best_clf, X)

# %% [markdown]
# # Plot `Survived` by `Sex`

# %%
survived_by_sex = df.groupby(['Sex', 'Survived'])['Survived'].count().unstack()
survived_by_sex.plot(kind='bar', figsize=(4, 3))
plt.xlabel('Sex (0=Male, 1=Female)')
plt.ylabel('#Passengers')
plt.legend(['Not Survived', 'Survived'])
plt.tight_layout()

# %% [markdown]
# # Training a random forest

# %%
from sklearn.ensemble import RandomForestClassifier

def train_forest(X, y, X_test=None, y_test=None):
    param_grid_rf = {
        'n_estimators': [5, 10, 100, 200, 300],
        'max_depth': [3, 5, 10, 15],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'max_features': ['sqrt', 'log2']
    }
    rf_clf = RandomForestClassifier(random_state=seed)
    random_search_rf = RandomizedSearchCV(estimator=rf_clf, param_distributions=param_grid_rf, n_iter=100, cv=5, scoring='accuracy', random_state=seed)
    random_search_rf.fit(X, y)
    best_rf_clf = random_search_rf.best_estimator_
    print("Best Classifier:", best_rf_clf)
    test_score = None
    if X_test is not None:
        y_pred = best_clf.predict(X_test)
        test_score = accuracy_score(y_test, y_pred)
    return best_rf_clf, float(random_search_rf.best_score_), test_score

best_clf, train_score, test_score = train_forest(X, y)
train_score, test_score
# Out:
# Best Classifier: RandomForestClassifier(max_depth=15, max_features='log2', min_samples_split=5,
#                        n_estimators=300, random_state=42)
# (0.8339150084740442, None)

# %% [markdown]
# # Feature engineering

# %%
def preprocess(df):
    df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
    df['FarePerPerson'] = df['Fare'] / df['FamilySize']
    df['IsAlone'] = (df['FamilySize'] == 1).astype(int)
    
    df['Title'] = df['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
    df['Title'] = df['Title'].replace(['Lady', 'Countess', 'Capt', 'Col', 'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
    df['Title'] = df['Title'].replace('Mlle', 'Miss').replace('Ms', 'Miss').replace('Mme', 'Mrs')
    
    df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})
    
    df['Age']=df['Age'].fillna(df['Age'].mean())
    df['Age'] = pd.cut(df['Age'], bins=[0, 12, 18, 35, 60, 100], labels=['Child', 'Teenager', 'Young', 'Adult', 'Senior'])
    
    df = pd.get_dummies(df, columns=['Title', 'Age', "Embarked"])  # , drop_first=True
    df = df.drop(['Name', 'PassengerId', 'Cabin', 'Ticket'], axis=1)
    return df, df.drop('Survived', axis=1), df['Survived']

df, X, y = preprocess(pd.read_csv('datasets/titanic/train.csv'))
# X_test, y_test = preprocess(pd.read_csv('datasets/titanic/test.csv'))

# %% [markdown]
# # Retraining the decision tree

# %%
best_clf, train_score, test_score = train_tree(X, y)
train_score, test_score
# Out:
# Best Classifier: DecisionTreeClassifier(criterion='entropy', max_depth=5, max_features='log2',
#                        min_samples_leaf=2, random_state=42)
# (0.8204067541271733, None)

# %%
feature_relevance(best_clf, X)

# %% [markdown]
# # Retraining the random forest

# %%
best_clf, train_score, test_score = train_forest(X, y)
train_score, test_score
# Out:
# Best Classifier: RandomForestClassifier(max_depth=5, n_estimators=5, random_state=42)
# (0.8316615403929445, None)

# %%
feature_relevance(best_clf, X)

# %% [markdown]
# # Some insights

# %%
import seaborn as sns

def plot(df, prefix):
    columns = [col for col in df.columns if col.startswith(prefix)]
    melted_df = df.melt(id_vars=['Survived'], value_vars=columns, var_name=prefix, value_name='Value')
    melted_df = melted_df[melted_df["Value"]].drop("Value", axis=1)
    melted_df[prefix] = melted_df[prefix].replace(prefix + "_", "", regex=True)
    plt.figure(figsize=(3, 2))
    sns.countplot(data=melted_df, x=prefix, hue='Survived')
    plt.legend(title='Survived', loc='upper right')

for x in ["Age", "Title"]: plot(df, x)

# %%
from sklearn.neural_network import MLPClassifier

def train_mlp(X, y, X_test=None, y_test=None):
    param_grid = {
        'hidden_layer_sizes': [(100), (10, 10), (10, 10, 10)],
        'activation': ["tanh", "relu"],
        "max_iter": [100, 1000, 10000],
        "learning_rate_init": [0.001, 0.01, 0.1],
        "solver": ["adam", "sgd"]
    }
    nn = MLPClassifier(random_state=seed)
    random_search = RandomizedSearchCV(estimator=nn, param_distributions=param_grid, n_iter=100, cv=5, scoring='accuracy', random_state=seed)
    random_search.fit(X, y)
    best = random_search.best_estimator_
    print("Best Classifier:", best)
    test_score = None
    if X_test is not None:
        y_pred = best_clf.predict(X_test)
        test_score = accuracy_score(y_test, y_pred)
    return best, float(random_search.best_score_), test_score

best_clf, train_score, test_score = train_mlp(X, y)
train_score, test_score
# Out:
# Best Classifier: MLPClassifier(hidden_layer_sizes=100, max_iter=100, random_state=42)
# (0.8293955181721172, None)

# %% [markdown]
# # Running AutoML

# %%
from flaml import AutoML

automl_settings = {
    "time_budget": 60,  # in seconds
    "metric": "accuracy",
    "task": "classification",
}

automl = AutoML()
automl.fit(X, y, **automl_settings)
# Out:
# [flaml.automl.logger: 11-12 17:13:39] {1728} INFO - task = classification
# [flaml.automl.logger: 11-12 17:13:39] {1739} INFO - Evaluation method: cv
# [flaml.automl.logger: 11-12 17:13:39] {1838} INFO - Minimizing error metric: 1-accuracy
# [flaml.automl.logger: 11-12 17:13:39] {1955} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'sgd', 'lrl1']
# [flaml.automl.logger: 11-12 17:13:39] {2258} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:39] {2393} INFO - Estimated sufficient time budget=1852s. Estimated necessary time budget=43s.
# [flaml.automl.logger: 11-12 17:13:39] {2442} INFO -  at 0.2s,	estimator lgbm's best error=0.2166,	best estimator lgbm's best error=0.2166
# [flaml.automl.logger: 11-12 17:13:39] {2258} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:39] {2442} INFO -  at 0.4s,	estimator lgbm's best error=0.2166,	best estimator lgbm's best error=0.2166
# [flaml.automl.logger: 11-12 17:13:39] {2258} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:40] {2442} INFO -  at 0.5s,	estimator lgbm's best error=0.1773,	best estimator lgbm's best error=0.1773
# [flaml.automl.logger: 11-12 17:13:40] {2258} INFO - iteration 3, current learner sgd
# [flaml.automl.logger: 11-12 17:13:40] {2442} INFO -  at 0.6s,	estimator sgd's best error=0.3838,	best estimator lgbm's best error=0.1773
# [flaml.automl.logger: 11-12 17:13:40] {2258} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:40] {2442} INFO -  at 0.9s,	estimator lgbm's best error=0.1740,	best estimator lgbm's best error=0.1740
# [flaml.automl.logger: 11-12 17:13:40] {2258} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:40] {2442} INFO -  at 1.1s,	estimator lgbm's best error=0.1740,	best estimator lgbm's best error=0.1740
# [flaml.automl.logger: 11-12 17:13:40] {2258} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:40] {2442} INFO -  at 1.4s,	estimator lgbm's best error=0.1740,	best estimator lgbm's best error=0.1740
# [flaml.automl.logger: 11-12 17:13:40] {2258} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:41] {2442} INFO -  at 1.6s,	estimator lgbm's best error=0.1695,	best estimator lgbm's best error=0.1695
# [flaml.automl.logger: 11-12 17:13:41] {2258} INFO - iteration 8, current learner sgd
# [flaml.automl.logger: 11-12 17:13:41] {2442} INFO -  at 1.7s,	estimator sgd's best error=0.2873,	best estimator lgbm's best error=0.1695
# [flaml.automl.logger: 11-12 17:13:41] {2258} INFO - iteration 9, current learner sgd
# [flaml.automl.logger: 11-12 17:13:41] {2442} INFO -  at 1.8s,	estimator sgd's best error=0.2873,	best estimator lgbm's best error=0.1695
# [flaml.automl.logger: 11-12 17:13:41] {2258} INFO - iteration 10, current learner xgboost
# [flaml.automl.logger: 11-12 17:13:41] {2442} INFO -  at 2.2s,	estimator xgboost's best error=0.2177,	best estimator lgbm's best error=0.1695
# [flaml.automl.logger: 11-12 17:13:41] {2258} INFO - iteration 11, current learner extra_tree
# [flaml.automl.logger: 11-12 17:13:42] {2442} INFO -  at 2.8s,	estimator extra_tree's best error=0.2144,	best estimator lgbm's best error=0.1695
# [flaml.automl.logger: 11-12 17:13:42] {2258} INFO - iteration 12, current learner rf
# [flaml.automl.logger: 11-12 17:13:42] {2442} INFO -  at 3.4s,	estimator rf's best error=0.2368,	best estimator lgbm's best error=0.1695
# [flaml.automl.logger: 11-12 17:13:42] {2258} INFO - iteration 13, current learner xgboost
# [flaml.automl.logger: 11-12 17:13:43] {2442} INFO -  at 3.6s,	estimator xgboost's best error=0.2177,	best estimator lgbm's best error=0.1695
# [flaml.automl.logger: 11-12 17:13:43] {2258} INFO - iteration 14, current learner extra_tree
# [flaml.automl.logger: 11-12 17:13:43] {2442} INFO -  at 4.2s,	estimator extra_tree's best error=0.1987,	best estimator lgbm's best error=0.1695
# [flaml.automl.logger: 11-12 17:13:43] {2258} INFO - iteration 15, current learner xgboost
# [flaml.automl.logger: 11-12 17:13:43] {2442} INFO -  at 4.4s,	estimator xgboost's best error=0.1953,	best estimator lgbm's best error=0.1695
# [flaml.automl.logger: 11-12 17:13:43] {2258} INFO - iteration 16, current learner sgd
# [flaml.automl.logger: 11-12 17:13:44] {2442} INFO -  at 4.4s,	estimator sgd's best error=0.2682,	best estimator lgbm's best error=0.1695
# [flaml.automl.logger: 11-12 17:13:44] {2258} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:44] {2442} INFO -  at 4.6s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:44] {2258} INFO - iteration 18, current learner extra_tree
# [flaml.automl.logger: 11-12 17:13:44] {2442} INFO -  at 5.1s,	estimator extra_tree's best error=0.1987,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:44] {2258} INFO - iteration 19, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:45] {2442} INFO -  at 5.4s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:45] {2258} INFO - iteration 20, current learner rf
# [flaml.automl.logger: 11-12 17:13:45] {2442} INFO -  at 6.0s,	estimator rf's best error=0.2076,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:45] {2258} INFO - iteration 21, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:45] {2442} INFO -  at 6.2s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:45] {2258} INFO - iteration 22, current learner rf
# [flaml.automl.logger: 11-12 17:13:46] {2442} INFO -  at 6.7s,	estimator rf's best error=0.2076,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:46] {2258} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:46] {2442} INFO -  at 7.0s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:46] {2258} INFO - iteration 24, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:46] {2442} INFO -  at 7.2s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:46] {2258} INFO - iteration 25, current learner sgd
# [flaml.automl.logger: 11-12 17:13:46] {2442} INFO -  at 7.2s,	estimator sgd's best error=0.2334,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:46] {2258} INFO - iteration 26, current learner sgd
# [flaml.automl.logger: 11-12 17:13:46] {2442} INFO -  at 7.4s,	estimator sgd's best error=0.2334,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:46] {2258} INFO - iteration 27, current learner rf
# [flaml.automl.logger: 11-12 17:13:47] {2442} INFO -  at 8.0s,	estimator rf's best error=0.2020,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:47] {2258} INFO - iteration 28, current learner sgd
# [flaml.automl.logger: 11-12 17:13:47] {2442} INFO -  at 8.1s,	estimator sgd's best error=0.2289,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:47] {2258} INFO - iteration 29, current learner extra_tree
# [flaml.automl.logger: 11-12 17:13:48] {2442} INFO -  at 9.1s,	estimator extra_tree's best error=0.1818,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:48] {2258} INFO - iteration 30, current learner extra_tree
# [flaml.automl.logger: 11-12 17:13:49] {2442} INFO -  at 9.5s,	estimator extra_tree's best error=0.1818,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:49] {2258} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:49] {2442} INFO -  at 9.7s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:49] {2258} INFO - iteration 32, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:49] {2442} INFO -  at 9.9s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:49] {2258} INFO - iteration 33, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:49] {2442} INFO -  at 10.0s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:49] {2258} INFO - iteration 34, current learner extra_tree
# [flaml.automl.logger: 11-12 17:13:50] {2442} INFO -  at 10.6s,	estimator extra_tree's best error=0.1818,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:50] {2258} INFO - iteration 35, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:50] {2442} INFO -  at 10.8s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:50] {2258} INFO - iteration 36, current learner xgboost
# [flaml.automl.logger: 11-12 17:13:50] {2442} INFO -  at 11.0s,	estimator xgboost's best error=0.1695,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:50] {2258} INFO - iteration 37, current learner extra_tree
# [flaml.automl.logger: 11-12 17:13:51] {2442} INFO -  at 11.5s,	estimator extra_tree's best error=0.1818,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:51] {2258} INFO - iteration 38, current learner xgboost
# [flaml.automl.logger: 11-12 17:13:51] {2442} INFO -  at 11.7s,	estimator xgboost's best error=0.1695,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:51] {2258} INFO - iteration 39, current learner xgboost
# [flaml.automl.logger: 11-12 17:13:51] {2442} INFO -  at 11.9s,	estimator xgboost's best error=0.1695,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:51] {2258} INFO - iteration 40, current learner xgboost
# [flaml.automl.logger: 11-12 17:13:51] {2442} INFO -  at 12.2s,	estimator xgboost's best error=0.1695,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:51] {2258} INFO - iteration 41, current learner xgboost
# [flaml.automl.logger: 11-12 17:13:51] {2442} INFO -  at 12.4s,	estimator xgboost's best error=0.1695,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:51] {2258} INFO - iteration 42, current learner xgboost
# [flaml.automl.logger: 11-12 17:13:52] {2442} INFO -  at 12.6s,	estimator xgboost's best error=0.1695,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:52] {2258} INFO - iteration 43, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:52] {2442} INFO -  at 12.7s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:52] {2258} INFO - iteration 44, current learner xgboost
# [flaml.automl.logger: 11-12 17:13:52] {2442} INFO -  at 12.9s,	estimator xgboost's best error=0.1695,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:52] {2258} INFO - iteration 45, current learner sgd
# [flaml.automl.logger: 11-12 17:13:52] {2442} INFO -  at 13.0s,	estimator sgd's best error=0.2289,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:52] {2258} INFO - iteration 46, current learner xgboost
# [flaml.automl.logger: 11-12 17:13:52] {2442} INFO -  at 13.2s,	estimator xgboost's best error=0.1695,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:52] {2258} INFO - iteration 47, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:52] {2442} INFO -  at 13.3s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:52] {2258} INFO - iteration 48, current learner xgboost
# [flaml.automl.logger: 11-12 17:13:53] {2442} INFO -  at 13.5s,	estimator xgboost's best error=0.1695,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:53] {2258} INFO - iteration 49, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:53] {2442} INFO -  at 13.7s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:53] {2258} INFO - iteration 50, current learner xgboost
# [flaml.automl.logger: 11-12 17:13:53] {2442} INFO -  at 13.9s,	estimator xgboost's best error=0.1695,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:53] {2258} INFO - iteration 51, current learner sgd
# [flaml.automl.logger: 11-12 17:13:53] {2442} INFO -  at 14.0s,	estimator sgd's best error=0.2289,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:53] {2258} INFO - iteration 52, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:53] {2442} INFO -  at 14.2s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:53] {2258} INFO - iteration 53, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:53] {2442} INFO -  at 14.3s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:53] {2258} INFO - iteration 54, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:54] {2442} INFO -  at 14.5s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:54] {2258} INFO - iteration 55, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:54] {2442} INFO -  at 14.7s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:54] {2258} INFO - iteration 56, current learner xgboost
# [flaml.automl.logger: 11-12 17:13:54] {2442} INFO -  at 14.9s,	estimator xgboost's best error=0.1695,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:54] {2258} INFO - iteration 57, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:54] {2442} INFO -  at 15.0s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:54] {2258} INFO - iteration 58, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:54] {2442} INFO -  at 15.2s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:54] {2258} INFO - iteration 59, current learner xgboost
# [flaml.automl.logger: 11-12 17:13:55] {2442} INFO -  at 15.4s,	estimator xgboost's best error=0.1694,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:55] {2258} INFO - iteration 60, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:55] {2442} INFO -  at 15.6s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:55] {2258} INFO - iteration 61, current learner rf
# [flaml.automl.logger: 11-12 17:13:55] {2442} INFO -  at 15.9s,	estimator rf's best error=0.2020,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:55] {2258} INFO - iteration 62, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:55] {2442} INFO -  at 16.1s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:55] {2258} INFO - iteration 63, current learner extra_tree
# [flaml.automl.logger: 11-12 17:13:56] {2442} INFO -  at 16.6s,	estimator extra_tree's best error=0.1728,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:56] {2258} INFO - iteration 64, current learner extra_tree
# [flaml.automl.logger: 11-12 17:13:56] {2442} INFO -  at 17.4s,	estimator extra_tree's best error=0.1728,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:56] {2258} INFO - iteration 65, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:57] {2442} INFO -  at 17.6s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:57] {2258} INFO - iteration 66, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:57] {2442} INFO -  at 17.7s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:57] {2258} INFO - iteration 67, current learner extra_tree
# [flaml.automl.logger: 11-12 17:13:58] {2442} INFO -  at 18.6s,	estimator extra_tree's best error=0.1728,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:58] {2258} INFO - iteration 68, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:58] {2442} INFO -  at 18.8s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:58] {2258} INFO - iteration 69, current learner lgbm
# [flaml.automl.logger: 11-12 17:13:58] {2442} INFO -  at 18.9s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:58] {2258} INFO - iteration 70, current learner rf
# [flaml.automl.logger: 11-12 17:13:59] {2442} INFO -  at 19.4s,	estimator rf's best error=0.1941,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:59] {2258} INFO - iteration 71, current learner extra_tree
# [flaml.automl.logger: 11-12 17:13:59] {2442} INFO -  at 20.1s,	estimator extra_tree's best error=0.1684,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:13:59] {2258} INFO - iteration 72, current learner rf
# [flaml.automl.logger: 11-12 17:14:00] {2442} INFO -  at 20.7s,	estimator rf's best error=0.1941,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:00] {2258} INFO - iteration 73, current learner sgd
# [flaml.automl.logger: 11-12 17:14:00] {2442} INFO -  at 20.8s,	estimator sgd's best error=0.2289,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:00] {2258} INFO - iteration 74, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:00] {2442} INFO -  at 21.4s,	estimator extra_tree's best error=0.1684,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:00] {2258} INFO - iteration 75, current learner sgd
# [flaml.automl.logger: 11-12 17:14:01] {2442} INFO -  at 21.4s,	estimator sgd's best error=0.2289,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:01] {2258} INFO - iteration 76, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:01] {2442} INFO -  at 21.6s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:01] {2258} INFO - iteration 77, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:01] {2442} INFO -  at 21.8s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:01] {2258} INFO - iteration 78, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:02] {2442} INFO -  at 22.7s,	estimator extra_tree's best error=0.1684,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:02] {2258} INFO - iteration 79, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:02] {2442} INFO -  at 22.9s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:02] {2258} INFO - iteration 80, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:02] {2442} INFO -  at 23.1s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:02] {2258} INFO - iteration 81, current learner sgd
# [flaml.automl.logger: 11-12 17:14:02] {2442} INFO -  at 23.1s,	estimator sgd's best error=0.2289,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:02] {2258} INFO - iteration 82, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:03] {2442} INFO -  at 23.4s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:03] {2258} INFO - iteration 83, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:03] {2442} INFO -  at 24.2s,	estimator extra_tree's best error=0.1684,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:03] {2258} INFO - iteration 84, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:04] {2442} INFO -  at 25.4s,	estimator extra_tree's best error=0.1684,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:04] {2258} INFO - iteration 85, current learner sgd
# [flaml.automl.logger: 11-12 17:14:05] {2442} INFO -  at 25.6s,	estimator sgd's best error=0.2289,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:05] {2258} INFO - iteration 86, current learner rf
# [flaml.automl.logger: 11-12 17:14:06] {2442} INFO -  at 26.8s,	estimator rf's best error=0.1931,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:06] {2258} INFO - iteration 87, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:07] {2442} INFO -  at 27.5s,	estimator extra_tree's best error=0.1684,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:07] {2258} INFO - iteration 88, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:07] {2442} INFO -  at 27.6s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:07] {2258} INFO - iteration 89, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:07] {2442} INFO -  at 27.8s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:07] {2258} INFO - iteration 90, current learner sgd
# [flaml.automl.logger: 11-12 17:14:07] {2442} INFO -  at 27.9s,	estimator sgd's best error=0.2289,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:07] {2258} INFO - iteration 91, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:07] {2442} INFO -  at 28.0s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:07] {2258} INFO - iteration 92, current learner sgd
# [flaml.automl.logger: 11-12 17:14:07] {2442} INFO -  at 28.1s,	estimator sgd's best error=0.2289,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:07] {2258} INFO - iteration 93, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:08] {2442} INFO -  at 29.1s,	estimator extra_tree's best error=0.1684,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:08] {2258} INFO - iteration 94, current learner rf
# [flaml.automl.logger: 11-12 17:14:09] {2442} INFO -  at 29.7s,	estimator rf's best error=0.1931,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:09] {2258} INFO - iteration 95, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:09] {2442} INFO -  at 30.0s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:09] {2258} INFO - iteration 96, current learner sgd
# [flaml.automl.logger: 11-12 17:14:09] {2442} INFO -  at 30.0s,	estimator sgd's best error=0.2289,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:09] {2258} INFO - iteration 97, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:09] {2442} INFO -  at 30.2s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:09] {2258} INFO - iteration 98, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:09] {2442} INFO -  at 30.3s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:09] {2258} INFO - iteration 99, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:10] {2442} INFO -  at 30.6s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:10] {2258} INFO - iteration 100, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:10] {2442} INFO -  at 30.8s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:10] {2258} INFO - iteration 101, current learner sgd
# [flaml.automl.logger: 11-12 17:14:10] {2442} INFO -  at 30.9s,	estimator sgd's best error=0.2289,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:10] {2258} INFO - iteration 102, current learner rf
# [flaml.automl.logger: 11-12 17:14:11] {2442} INFO -  at 32.2s,	estimator rf's best error=0.1931,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:11] {2258} INFO - iteration 103, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:11] {2442} INFO -  at 32.4s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:11] {2258} INFO - iteration 104, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:12] {2442} INFO -  at 33.3s,	estimator extra_tree's best error=0.1684,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:12] {2258} INFO - iteration 105, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:13] {2442} INFO -  at 33.5s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:13] {2258} INFO - iteration 106, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:13] {2442} INFO -  at 33.8s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:13] {2258} INFO - iteration 107, current learner sgd
# [flaml.automl.logger: 11-12 17:14:13] {2442} INFO -  at 33.8s,	estimator sgd's best error=0.2289,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:13] {2258} INFO - iteration 108, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:13] {2442} INFO -  at 34.0s,	estimator lgbm's best error=0.1639,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:13] {2258} INFO - iteration 109, current learner sgd
# [flaml.automl.logger: 11-12 17:14:13] {2442} INFO -  at 34.1s,	estimator sgd's best error=0.2289,	best estimator lgbm's best error=0.1639
# [flaml.automl.logger: 11-12 17:14:13] {2258} INFO - iteration 110, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:14] {2442} INFO -  at 35.3s,	estimator extra_tree's best error=0.1616,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:14] {2258} INFO - iteration 111, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:15] {2442} INFO -  at 35.6s,	estimator lgbm's best error=0.1639,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:15] {2258} INFO - iteration 112, current learner sgd
# [flaml.automl.logger: 11-12 17:14:15] {2442} INFO -  at 35.7s,	estimator sgd's best error=0.2289,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:15] {2258} INFO - iteration 113, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:15] {2442} INFO -  at 36.3s,	estimator extra_tree's best error=0.1616,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:15] {2258} INFO - iteration 114, current learner sgd
# [flaml.automl.logger: 11-12 17:14:16] {2442} INFO -  at 36.5s,	estimator sgd's best error=0.2289,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:16] {2258} INFO - iteration 115, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:16] {2442} INFO -  at 36.6s,	estimator lgbm's best error=0.1639,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:16] {2258} INFO - iteration 116, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:16] {2442} INFO -  at 37.0s,	estimator lgbm's best error=0.1639,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:16] {2258} INFO - iteration 117, current learner sgd
# [flaml.automl.logger: 11-12 17:14:16] {2442} INFO -  at 37.1s,	estimator sgd's best error=0.2289,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:16] {2258} INFO - iteration 118, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:17] {2442} INFO -  at 38.2s,	estimator extra_tree's best error=0.1616,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:17] {2258} INFO - iteration 119, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:18] {2442} INFO -  at 38.5s,	estimator lgbm's best error=0.1639,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:18] {2258} INFO - iteration 120, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:19] {2442} INFO -  at 39.6s,	estimator extra_tree's best error=0.1616,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:19] {2258} INFO - iteration 121, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:19] {2442} INFO -  at 40.3s,	estimator extra_tree's best error=0.1616,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:19] {2258} INFO - iteration 122, current learner sgd
# [flaml.automl.logger: 11-12 17:14:19] {2442} INFO -  at 40.4s,	estimator sgd's best error=0.2289,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:19] {2258} INFO - iteration 123, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:21] {2442} INFO -  at 42.1s,	estimator extra_tree's best error=0.1616,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:21] {2258} INFO - iteration 124, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:21] {2442} INFO -  at 42.4s,	estimator lgbm's best error=0.1639,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:21] {2258} INFO - iteration 125, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:22] {2442} INFO -  at 42.9s,	estimator lgbm's best error=0.1639,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:22] {2258} INFO - iteration 126, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:22] {2442} INFO -  at 43.2s,	estimator lgbm's best error=0.1639,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:22] {2258} INFO - iteration 127, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:23] {2442} INFO -  at 43.6s,	estimator lgbm's best error=0.1639,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:23] {2258} INFO - iteration 128, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:23] {2442} INFO -  at 43.9s,	estimator lgbm's best error=0.1639,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:23] {2258} INFO - iteration 129, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:24] {2442} INFO -  at 44.6s,	estimator extra_tree's best error=0.1616,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:24] {2258} INFO - iteration 130, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:25] {2442} INFO -  at 45.7s,	estimator extra_tree's best error=0.1616,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:25] {2258} INFO - iteration 131, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:26] {2442} INFO -  at 47.2s,	estimator extra_tree's best error=0.1616,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:26] {2258} INFO - iteration 132, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:28] {2442} INFO -  at 48.6s,	estimator extra_tree's best error=0.1616,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:28] {2258} INFO - iteration 133, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:28] {2442} INFO -  at 48.9s,	estimator lgbm's best error=0.1639,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:28] {2258} INFO - iteration 134, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:28] {2442} INFO -  at 49.3s,	estimator lgbm's best error=0.1639,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:28] {2258} INFO - iteration 135, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:30] {2442} INFO -  at 50.5s,	estimator extra_tree's best error=0.1616,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:30] {2258} INFO - iteration 136, current learner sgd
# [flaml.automl.logger: 11-12 17:14:30] {2442} INFO -  at 50.6s,	estimator sgd's best error=0.2289,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:30] {2258} INFO - iteration 137, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:31] {2442} INFO -  at 51.6s,	estimator extra_tree's best error=0.1616,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:31] {2258} INFO - iteration 138, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:31] {2442} INFO -  at 51.9s,	estimator lgbm's best error=0.1639,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:31] {2258} INFO - iteration 139, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:32] {2442} INFO -  at 53.2s,	estimator extra_tree's best error=0.1616,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:32] {2258} INFO - iteration 140, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:33] {2442} INFO -  at 53.7s,	estimator lgbm's best error=0.1639,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:33] {2258} INFO - iteration 141, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:34] {2442} INFO -  at 54.8s,	estimator extra_tree's best error=0.1616,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:34] {2258} INFO - iteration 142, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:35] {2442} INFO -  at 55.4s,	estimator lgbm's best error=0.1639,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:35] {2258} INFO - iteration 143, current learner xgb_limitdepth
# [flaml.automl.logger: 11-12 17:14:35] {2442} INFO -  at 56.1s,	estimator xgb_limitdepth's best error=0.1650,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:35] {2258} INFO - iteration 144, current learner xgb_limitdepth
# [flaml.automl.logger: 11-12 17:14:36] {2442} INFO -  at 56.8s,	estimator xgb_limitdepth's best error=0.1650,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:36] {2258} INFO - iteration 145, current learner xgb_limitdepth
# [flaml.automl.logger: 11-12 17:14:36] {2442} INFO -  at 57.2s,	estimator xgb_limitdepth's best error=0.1650,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:36] {2258} INFO - iteration 146, current learner xgb_limitdepth
# [flaml.automl.logger: 11-12 17:14:37] {2442} INFO -  at 57.6s,	estimator xgb_limitdepth's best error=0.1650,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:37] {2258} INFO - iteration 147, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:37] {2442} INFO -  at 58.3s,	estimator extra_tree's best error=0.1616,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:37] {2258} INFO - iteration 148, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:38] {2442} INFO -  at 58.5s,	estimator lgbm's best error=0.1639,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:38] {2258} INFO - iteration 149, current learner extra_tree
# [flaml.automl.logger: 11-12 17:14:39] {2442} INFO -  at 59.4s,	estimator extra_tree's best error=0.1616,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:39] {2258} INFO - iteration 150, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:39] {2442} INFO -  at 59.6s,	estimator lgbm's best error=0.1639,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:39] {2258} INFO - iteration 151, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:39] {2442} INFO -  at 59.7s,	estimator lgbm's best error=0.1639,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:39] {2258} INFO - iteration 152, current learner lgbm
# [flaml.automl.logger: 11-12 17:14:39] {2442} INFO -  at 59.9s,	estimator lgbm's best error=0.1639,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:39] {2258} INFO - iteration 153, current learner lrl1
# [flaml.automl.logger: 11-12 17:14:39] {2442} INFO -  at 60.0s,	estimator lrl1's best error=0.3109,	best estimator extra_tree's best error=0.1616
# [flaml.automl.logger: 11-12 17:14:39] {2685} INFO - retrain extra_tree for 0.0s
# [flaml.automl.logger: 11-12 17:14:39] {2688} INFO - retrained model: ExtraTreesClassifier(criterion=np.str_('gini'),
#                      max_features=np.float64(0.14767434400801147),
#                      max_leaf_nodes=17, n_estimators=23, n_jobs=-1,
#                      random_state=12032022)
# [flaml.automl.logger: 11-12 17:14:39] {1985} INFO - fit succeeded
# [flaml.automl.logger: 11-12 17:14:39] {1986} INFO - Time taken to find the best model: 35.25633764266968

# %%
automl.model.estimator
# Out:
# ExtraTreesClassifier(criterion=np.str_('gini'),
#                      max_features=np.float64(0.14767434400801147),
#                      max_leaf_nodes=17, n_estimators=23, n_jobs=-1,
#                      random_state=12032022)

# %% [markdown]
# # Can you do better?

# %%
# Write your code here
